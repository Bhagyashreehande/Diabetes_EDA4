# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes_data=pd.read_csv('diabetes.csv')

# %%
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
diabetes_data_copy=diabetes_data.copy()

# %%
diabetes_data_copy
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_data_copy.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes_data_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']]=diabetes_data_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']].replace(0,np.NaN)

# %%
diabetes_data_copy.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False     True  False
# 1          False    False          False          False     True  False
# 2          False    False          False           True     True  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False     True  False
# 765        False    False          False          False    False  False
# 766        False    False          False           True     True  False
# 767        False    False          False          False     True  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
diabetes_data_copy.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
diabetes_data_copy.hist(figsize=(18,18))
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %%
diabetes_data_copy.boxplot(figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
diabetes_data_copy['Glucose'].fillna(diabetes_data_copy['Glucose'].mean(),inplace=True)

# %%
diabetes_data_copy['Glucose'].mean()
# Out:
# 121.68676277850587

# %%
diabetes_data_copy['BloodPressure'].fillna(diabetes_data_copy['BloodPressure'].mean(),inplace=True)

# %%
diabetes_data_copy['SkinThickness'].fillna(diabetes_data_copy['SkinThickness'].mean(),inplace=True)

# %%
diabetes_data_copy['BMI'].fillna(diabetes_data_copy['BMI'].mean(),inplace=True)

# %%
diabetes_data_copy['Insulin'].fillna(diabetes_data_copy['Insulin'].mean(),inplace=True)

# %%
diabetes_data_copy.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
diabetes_data_copy.dtypes
# Out:
# Pregnancies                   int64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                     float64
# dtype: object

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
s=msno.bar(diabetes_data_copy,color='pink')

# %%
msno.bar(diabetes_data)
# Out:
# <AxesSubplot:>

# %%
diabetes_data_copy_missing=diabetes_data_copy.copy()

# %%
diabetes_data_copy_missing
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
diabetes_data_copy_missing[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']]=diabetes_data_copy_missing[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']].replace(0,np.NaN)

# %%
msno.bar(diabetes_data_copy_missing)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
x=diabetes_data_copy_missing.drop(['Outcome'],axis=1)

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
y=diabetes_data_copy_missing['Outcome']

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=102)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 427            1    181.0           64.0       30.00000  180.000000  34.1
# 613            6    105.0           80.0       28.00000  155.548223  32.5
# 86            13    106.0           72.0       54.00000  155.548223  36.6
# 143           10    108.0           66.0       29.15342  155.548223  32.4
# 693            7    129.0           68.0       49.00000  125.000000  38.5
# ..           ...      ...            ...            ...         ...   ...
# 626            0    125.0           68.0       29.15342  155.548223  24.7
# 242            3    139.0           54.0       29.15342  155.548223  25.6
# 590           11    111.0           84.0       40.00000  155.548223  46.8
# 755            1    128.0           88.0       39.00000  110.000000  36.5
# 256            3    111.0           56.0       39.00000  155.548223  30.1
#
#      DiabetesPedigreeFunction  Age
# 427                     0.328   38
# ...

# %%
y_train
# Out:
# 427    1.0
# 613    NaN
# 86     NaN
# 143    1.0
# 693    1.0
#       ...
# 626    NaN
# 242    1.0
# 590    1.0
# 755    1.0
# 256    NaN
# Name: Outcome, Length: 537, dtype: float64

# %%
x_test
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 508            2   84.000000           50.0       23.00000   76.000000  30.4
# 512            9   91.000000           68.0       29.15342  155.548223  24.2
# 654            1  106.000000           70.0       28.00000  135.000000  34.2
# 189            5  139.000000           80.0       35.00000  160.000000  31.6
# 709            2   93.000000           64.0       32.00000  160.000000  38.0
# ..           ...         ...            ...            ...         ...   ...
# 696            3  169.000000           74.0       19.00000  125.000000  29.9
# 540            8  100.000000           74.0       40.00000  215.000000  39.4
# 557            8  110.000000           76.0       29.15342  155.548223  27.8
# 349            5  121.686763           80.0       32.00000  155.548223  41.0
# 133            8   84.000000           74.0       31.00000  155.548223  38.3
#
#      DiabetesPedigreeFunction  Age
# ...

# %%
y_test
# Out:
# 508    NaN
# 512    NaN
# 654    NaN
# 189    1.0
# 709    1.0
#       ...
# 696    1.0
# 540    1.0
# 557    NaN
# 349    1.0
# 133    NaN
# Name: Outcome, Length: 231, dtype: float64

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_std=StandardScaler()

# %%
x_std
# Out:
# StandardScaler()

# %%
type(x_std)
# Out:
# sklearn.preprocessing._data.StandardScaler

# %%
x_std.fit_transform(x)
# Out:
# array([[ 0.63994726,  0.86510807, -0.03351824, ...,  0.16629174,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.20616153, -0.52985903, ..., -0.85253118,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.0158134 , -0.69530596, ..., -1.33283341,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.0225789 , -0.03351824, ..., -0.91074963,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14180757, -1.02619983, ..., -0.34311972,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.94314317, -0.19896517, ..., -0.29945588,
#         -0.47378505, -0.87137393]])

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0       35.00000  155.548223  33.6
# 1              1     85.0           66.0       29.00000  155.548223  26.6
# 2              8    183.0           64.0       29.15342  155.548223  23.3
# 3              1     89.0           66.0       23.00000   94.000000  28.1
# 4              0    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0       48.00000  180.000000  32.9
# 764            2    122.0           70.0       27.00000  155.548223  36.8
# 765            5    121.0           72.0       23.00000  112.000000  26.2
# 766            1    126.0           60.0       29.15342  155.548223  30.1
# 767            1     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
x_std.fit_transform(x_std.fit_transform(x), columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17720/304701163.py in <module>
# ----> 1 x_std.fit_transform(x_std.fit_transform(x), columns=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#       2        'BMI', 'DiabetesPedigreeFunction', 'Age'])
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# TypeError: fit() got an unexpected keyword argument 'columns'
